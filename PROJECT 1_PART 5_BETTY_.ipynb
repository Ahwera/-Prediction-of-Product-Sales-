# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahwera/-Prediction-of-Product-Sales-/blob/main/PROJECT%201_PART%205_BETTY_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imporrt libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn import set_config
set_config(transform_output='pandas')
# New Imports
from sklearn.pipeline import make_pipeline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the data
filename = "/content/drive/MyDrive/sales_predictions_2023.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
#duplicate rows
duplicate_rows =df.duplicated()
duplicate_rows.sum()
# Out:
# 0

# %%
#Check for null values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
median_value = df['Item_Weight'].median()
df['Item_Weight'] = df['Item_Weight'].fillna(median_value)

# %% [markdown]
# ##Checking to make sure the values for Item_Weight colum were filled in

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna(value = 'Unknown')

# %%
df['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium     2793
# Unknown    2410
# Small      2388
# High        932
# Name: count, dtype: int64

# %% [markdown]
# ##Checking to make sure the values for the Outlet_Size column were filled

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ## Fixing Data Types

# %% [markdown]
# ### Address the data types to match the data dictionary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## No inconsistencies were found on data types

# %%
#Drop Item_Identifier because it has very high cardinality.
# Assign the target column to y
y = df['Item_Outlet_Sales']
# Assign the features to X (In this case we include all columns except the target column)
X = df.drop(columns = 'Item_Identifier')

# %%
# check the target
y.head()
# Out:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
# check the features
X.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998     Unknown
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
# import the train_test_split method here
from sklearn.model_selection import train_test_split

# %%
# use the dataframe from above
y = df['Item_Outlet_Sales']
X = df.drop(columns = ["Item_Outlet_Sales"])
X_train,X_test, y_train, y_test = train_test_split(X,y,random_state= 42)

# %%
print(X.shape)
print(y.shape)
print(X_train.shape[0]/X.shape[0])
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8523, 11)
# (8523,)
# 0.7499706676053033
# (2131, 11)
# (6392,)
# (2131,)

# %%
mean_Item_Visibility = df['Item_Visibility'].mean()
df.loc[df['Item_Visibility'] == 0, 'Item_Visibility'] = mean_Item_Visibility

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count   8523.00000      8523.000000  8523.000000                8523.000000
# mean      12.81342         0.070213   140.992782                1997.831867
# std        4.22724         0.048742    62.275067                   8.371760
# min        4.55500         0.003575    31.290000                1985.000000
# 25%        9.31000         0.033085    93.826500                1987.000000
# 50%       12.60000         0.062517   143.012800                1999.000000
# 75%       16.00000         0.094585   185.643700                2004.000000
# max       21.35000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ## Ordinal pipeline

# %%
#Check for inconsistent categories
categories = df['Outlet_Size'].unique()
categories
# Out:
# array(['Medium', 'Unknown', 'High', 'Small'], dtype=object)

# %%
# Defining ordinal lists of types of features
ordinal_cols = ["Outlet_Size"]
impute_common = SimpleImputer(strategy='most_frequent')
shelf_order = ['Medium', 'Unknown', 'High', 'Small']
ord_encoder = OrdinalEncoder(categories=[shelf_order])

# %%
# instantiate preprocessors
scaler = StandardScaler()

# %%
ord_pipeline =make_pipeline(impute_common,ord_encoder,scaler)
ord_pipeline
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('ordinalencoder',
#                  OrdinalEncoder(categories=[['Medium', 'Unknown', 'High',
#                                              'Small']])),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# ## nominal pipeline

# %%
# Defining lists of types of features
nom_cols = X_train.select_dtypes("object").drop(columns=ordinal_cols).columns
impute_missing = SimpleImputer(strategy='constant',fill_value='missing')
ohe_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
ohe_pipe = make_pipeline(impute_missing, ohe_encoder)
ohe_pipe
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='missing', strategy='constant')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# ## Numerical pipeline

# %%
num_columns = X_train.select_dtypes("number").columns
impute_mean = SimpleImputer(strategy='mean')
scaler = StandardScaler()
num_pipeline = make_pipeline(impute_mean,scaler)
num_pipeline
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# ## Column Transformer

# %% [markdown]
# ### defining tuples

# %%
# ordinal tuple
ord_tuple = ('ordinal',ord_pipeline, ordinal_cols)
ord_tuple
# Out:
# ('ordinal',
#  Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['Medium', 'Unknown', 'High',
#                                               'Small']])),
#                  ('standardscaler', StandardScaler())]),
#  ['Outlet_Size'])

# %%
# numeric tuple
num_tuple = ('numeric', num_pipeline, num_columns )
num_tuple
# Out:
# ('numeric',
#  Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                  ('standardscaler', StandardScaler())]),
#  Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#         'Outlet_Establishment_Year'],
#        dtype='object'))

# %%
# nominal tuple
#Onehot encoder
OneHotEncoder_tuple = ('categorical',ohe_pipe, nom_cols)
OneHotEncoder_tuple
# Out:
# ('categorical',
#  Pipeline(steps=[('simpleimputer',
#                   SimpleImputer(fill_value='missing', strategy='constant')),
#                  ('onehotencoder',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#         'Outlet_Location_Type', 'Outlet_Type'],
#        dtype='object'))

# %% [markdown]
# ## Instantiate the transformer

# %%
from sklearn.compose import ColumnTransformer
col_transformer = ColumnTransformer([num_tuple, ord_tuple, OneHotEncoder_tuple],
                                    verbose_feature_names_out=False)
col_transformer
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')),
#                                 ('ordinal',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categ...
#                                  ['Outlet_Size']),
#                                 ('categorical',
# ...

# %%
#Fit the column transformer object to the training data
# Fit on training data
col_transformer.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year'],
#       dtype='object')),
#                                 ('ordinal',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categ...
#                                  ['Outlet_Size']),
#                                 ('categorical',
# ...

# %%
#Save the transformed training data as X_train_processed
X_train_processed = col_transformer.transform(X_train)
X_train_processed.head()
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 4776     0.829446        -0.712775  1.828109                   1.327849
# 7510     0.568634        -1.291052  0.603369                   1.327849
# 5828    -0.118961         1.813319  0.244541                   0.136187
# 5327    -1.156281        -1.004931 -0.952591                   0.732018
# 4810     1.540750        -0.965484 -0.336460                   0.493686
#
#       Outlet_Size  Item_Identifier_DRA12  Item_Identifier_DRA24  \
# 4776    -1.114696                    0.0                    0.0
# 7510    -1.114696                    0.0                    0.0
# 5828    -1.114696                    0.0                    0.0
# 5327     1.384183                    0.0                    0.0
# 4810    -0.281736                    0.0                    0.0
#
#       Item_Identifier_DRA59  Item_Identifier_DRB01  Item_Identifier_DRB13  \
# ...

# %%
X_test_processed = col_transformer.transform(X_test)
X_test_processed.head()
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 7503     0.343387        -0.776646 -0.998816                  -1.293807
# 2957    -1.166950         0.100317 -1.585194                  -0.102145
# 7031     0.390807        -0.482994 -1.595784                   0.136187
# 1084    -0.059686        -0.415440  0.506592                  -1.532139
# 856     -0.629915        -1.047426  0.886725                   0.732018
#
#       Outlet_Size  Item_Identifier_DRA12  Item_Identifier_DRA24  \
# 7503     0.551223                    0.0                    0.0
# 2957     1.384183                    0.0                    0.0
# 7031    -1.114696                    0.0                    0.0
# 1084    -1.114696                    0.0                    0.0
# 856      1.384183                    0.0                    0.0
#
#       Item_Identifier_DRA59  Item_Identifier_DRB01  Item_Identifier_DRB13  \
# ...
