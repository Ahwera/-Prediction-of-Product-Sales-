# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahwera/-Prediction-of-Product-Sales-/blob/main/PIPELINES_PRACTICE_BETTY_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imporrt libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn import set_config
set_config(transform_output='pandas')
# New Imports
from sklearn.pipeline import make_pipeline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the data
filename = "/content/drive/MyDrive/BASE SALES UPLOAD/cereal-kaggle-crawford-modified - sheet 1.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C       NaN        4  1.0     130   10.0
# 1          100% Natural Bran   Q    C     120.0        3  5.0      15    2.0
# 2                   All-Bran   K    C      70.0        4  1.0     260    9.0
# 3  All-Bran with Extra Fiber   K    C      50.0        4  0.0     140   14.0
# 4             Almond Delight   R    C       NaN        2  2.0     200    1.0
#
#    carbo  sugars  potass  vitamins shelf  weight  cups     rating
# 0    5.0     6.0     280        25   top     1.0  0.33  68.402973
# 1    8.0     8.0     135         0   top     1.0  1.00  33.983679
# 2    7.0     5.0     320        25   top     1.0  0.33  59.425505
# 3    8.0     0.0     330        25   top     1.0  0.50  93.704912
# 4   14.0     8.0      -1        25   NaN     1.0  0.75  34.384843

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   72.000000  77.000000  70.000000   77.000000  71.000000  77.000000
# mean   106.388889   2.545455   1.042857  159.675325   2.164789  14.597403
# std     18.862404   1.094790   1.027671   83.832295   2.436514   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   0.500000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins     weight       cups     rating
# count  71.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.887324   96.077922   28.246753   1.029610   0.821039  42.665705
# std     4.457896   71.286813   22.342523   0.150477   0.232716  14.047289
# min    -1.000000   -1.000000    0.000000   0.500000   0.250000  18.042851
# 25%     3.000000   40.000000   25.000000   1.000000   0.670000  33.174094
# 50%     7.000000   90.000000   25.000000   1.000000   0.750000  40.400208
# 75%    11.000000  120.000000   25.000000   1.000000   1.000000  50.828392
# max    15.000000  330.000000  100.000000   1.500000   1.500000  93.704912

# %%
# Assign the target column to y
y = df['rating']
# Assign the features to X (In this case we include all columns except the target column)
X = df.drop(columns = 'name')

# %%
# check the target
y.head()
# Out:
# 0    68.402973
# 1    33.983679
# 2    59.425505
# 3    93.704912
# 4    34.384843
# Name: rating, dtype: float64

# %%
# check the features
X.head()
# Out:
#   mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0   N    C       NaN        4  1.0     130   10.0    5.0     6.0     280
# 1   Q    C     120.0        3  5.0      15    2.0    8.0     8.0     135
# 2   K    C      70.0        4  1.0     260    9.0    7.0     5.0     320
# 3   K    C      50.0        4  0.0     140   14.0    8.0     0.0     330
# 4   R    C       NaN        2  2.0     200    1.0   14.0     8.0      -1
#
#    vitamins shelf  weight  cups     rating
# 0        25   top     1.0  0.33  68.402973
# 1         0   top     1.0  1.00  33.983679
# 2        25   top     1.0  0.33  59.425505
# 3        25   top     1.0  0.50  93.704912
# 4        25   NaN     1.0  0.75  34.384843

# %%
# Let us import the train_test_split method here
from sklearn.model_selection import train_test_split

# %%
# use the dataframe from above
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X.shape)
print(y.shape)
print(X_train.shape[0]/X.shape[0])
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (77, 15)
# (77,)
# 0.7402597402597403
# (20, 15)
# (57,)
# (20,)

# %%
X.head()
# Out:
#   mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# 0   N    C       NaN        4  1.0     130   10.0    5.0     6.0     280
# 1   Q    C     120.0        3  5.0      15    2.0    8.0     8.0     135
# 2   K    C      70.0        4  1.0     260    9.0    7.0     5.0     320
# 3   K    C      50.0        4  0.0     140   14.0    8.0     0.0     330
# 4   R    C       NaN        2  2.0     200    1.0   14.0     8.0      -1
#
#    vitamins shelf  weight  cups     rating
# 0        25   top     1.0  0.33  68.402973
# 1         0   top     1.0  1.00  33.983679
# 2        25   top     1.0  0.33  59.425505
# 3        25   top     1.0  0.50  93.704912
# 4        25   NaN     1.0  0.75  34.384843

# %% [markdown]
# ## Ordinal pipeline

# %%
# Defining ordinal lists of types of features
ordinal_cols = ["shelf"]
impute_common = SimpleImputer(strategy='most_frequent')
shelf_order = ['bottom', 'middle', 'top']
ord_encoder = OrdinalEncoder(categories=[shelf_order])

# %%
# instantiate preprocessors
scaler = StandardScaler()

# %%
ord_pipeline =make_pipeline(impute_common,ord_encoder,scaler)
ord_pipeline
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('ordinalencoder',
#                  OrdinalEncoder(categories=[['bottom', 'middle', 'top']])),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# ##nominal pipeline

# %%
# Defining lists of types of features
nom_cols = X_train.select_dtypes("object").drop(columns=ordinal_cols).columns
impute_missing = SimpleImputer(strategy='constant',fill_value='missing')
ohe_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
ohe_pipe = make_pipeline(impute_missing, ohe_encoder)
ohe_pipe
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='missing', strategy='constant')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# ## Numerical pipeline

# %%
num_columns = X_train.select_dtypes("number").columns
impute_mean = SimpleImputer(strategy='mean')
scaler = StandardScaler()
num_pipeline = make_pipeline(impute_mean,scaler)
num_pipeline
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])
